# %% [markdown]
# <a href="https://colab.research.google.com/github/mithlohar144/Air_Quality_Prediction_System/blob/main/Air.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reasoning**:
# The previous command failed because the pandas library was not imported. Import pandas and try again to load the dataset and display the head.

# %%
print("Key Findings from Exploratory Data Analysis (EDA):\n")

print("1. Descriptive Statistics, Distributions, and Correlation Matrix of Numerical Features:")
display(df_cleaned[numerical_cols].describe())

print("\nSummary of Distributions:")
print("- so2: The distribution is skewed to the right, indicating a concentration of lower values with some higher outliers.")
print("- no2: The distribution is also skewed to the right, similar to so2.")
print("- rspm: The distribution is less skewed than so2 and no2, appearing closer to a normal distribution but still with a tail to the right.")
print("- spm: The distribution is skewed to the right, with a wide spread of values.")

print("\nCorrelation Matrix:")
display(correlation_matrix)

print("\nSummary of Correlations:")
print("- There is a moderate positive correlation between no2 and rspm (approx. 0.37).")
print("- There is a moderate positive correlation between rspm and spm (approx. 0.48).")
print("- The correlations between so2 and other pollutants are relatively weak.")

print("\n2. Distributions of Categorical Variables:")
print("\nDistribution of States:")
display(df_cleaned['state'].value_counts().head())
print("\nDistribution of Types of Monitoring Stations:")
display(df_cleaned['type'].value_counts().head())
print("\nTop 20 Locations by Frequency:")
display(df_cleaned['location'].value_counts().nlargest(20).head())

print("\nSummary of Categorical Distributions:")
print(f"- The dataset contains data from {df_cleaned['state'].nunique()} states. The top states with the most observations are displayed.")
print(f"- There are {df_cleaned['type'].nunique()} types of monitoring stations. The most frequent types are displayed.")
print(f"- The data is concentrated in certain locations, with the top 20 locations accounting for a significant portion of the observations.")


print("\n3. Yearly Trends of Numerical Air Quality Parameters:")
display(yearly_trend.head())

print("\nSummary of Yearly Trends:")
print("- so2: Shows a general decreasing trend over the years.")
print("- no2: Shows some fluctuations but a relatively stable or slightly decreasing trend in later years.")
print("- rspm: Shows some year-to-year variation but no clear long-term increasing or decreasing trend.")
print("- spm: Shows significant year-to-year variation with no consistent trend, likely due to high variability and imputation.")

print("\n4. Comprehensive Summary of Key Findings:")
print("The air quality dataset provides valuable insights into pollution levels across India. The numerical features (so2, no2, rspm, spm) generally exhibit right-skewed distributions, indicating the prevalence of lower pollution levels but with instances of significantly higher values. Moderate positive correlations exist between no2, rspm, and spm. The data covers numerous states and types of monitoring stations, with observations concentrated in specific locations. Analysis of yearly trends suggests a decrease in so2 levels over time, while no2 and rspm show more stable or fluctuating patterns. The trend for spm is less clear due to high variability.")
# Out:
# Key Findings from Exploratory Data Analysis (EDA):
#
# 1. Descriptive Statistics, Distributions, and Correlation Matrix of Numerical Features:
#                  so2            no2           rspm            spm
# count  435742.000000  435742.000000  435742.000000  435742.000000
# mean       10.555637      25.509149     108.010719     219.332952
# std         8.316006      16.179947      66.758646      94.080076
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     203.000000
# 50%         9.000000      22.300000      97.666667     220.783480
# 75%        13.000000      32.000000     135.000000     220.783480
# max        47.400000      92.500000     354.000000     601.000000
# Summary of Distributions:
# - so2: The distribution is skewed to the right, indicating a concentration of lower values with some higher outliers.
# - no2: The distribution is also skewed to the right, similar to so2.
# ...

# %% [markdown]
# **Reasoning**:
# Analyze the trend of air quality parameters over time using line plots, aggregating data by year as requested in step 6 of the instructions.

# %%
# Aggregate data by year and calculate the mean for numerical columns
df_cleaned['year'] = df_cleaned['date'].dt.year
yearly_trend = df_cleaned.groupby('year')[numerical_cols].mean().reset_index()

# Plot the yearly trend for each air quality parameter
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.lineplot(data=yearly_trend, x='year', y=col)
    plt.title(f'Yearly Trend of {col}')
    plt.xlabel('Year')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Explore the distribution of categorical variables ('state', 'location', 'type') using count plots as requested in step 5 of the instructions. Due to the large number of unique values in 'location', only the top locations will be plotted for better visualization.

# %%
categorical_cols_to_plot = ['state', 'type']

plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_cols_to_plot):
    plt.subplot(1, 2, i + 1)
    sns.countplot(y=df_cleaned[col], order=df_cleaned[col].value_counts().index)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Explore the distribution of the top locations
plt.figure(figsize=(10, 8))
top_locations = df_cleaned['location'].value_counts().nlargest(20).index
sns.countplot(y=df_cleaned['location'], order=top_locations)
plt.title('Top 20 Locations by Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Calculate and display the correlation matrix for the numerical columns and then create a heatmap of the correlation matrix to visualize the relationships, combining steps 3 and 4 of the instructions.

# %%
# Calculate the correlation matrix
correlation_matrix = df_cleaned[numerical_cols].corr()

# Display the correlation matrix
display(correlation_matrix)

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Air Quality Parameters')
plt.show()
# Out:
#            so2       no2      rspm       spm
# so2   1.000000  0.390892  0.184556  0.103968
# no2   0.390892  1.000000  0.367691  0.235563
# rspm  0.184556  0.367691  1.000000  0.477796
# spm   0.103968  0.235563  0.477796  1.000000

# %% [markdown]
# ## Perform exploratory data analysis (eda)
#
# ### Subtask:
# Analyze the distributions of key variables, identify correlations, and visualize the data to gain insights.

# %% [markdown]
# **Reasoning**:
# Calculate and display descriptive statistics for the numerical columns and then generate histograms for these columns to visualize their distributions, combining steps 1 and 2 of the instructions.

# %%
# Display descriptive statistics
display(df_cleaned[numerical_cols].describe())

# Generate histograms
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_cleaned[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
# Out:
#                  so2            no2           rspm            spm
# count  435742.000000  435742.000000  435742.000000  435742.000000
# mean       10.555637      25.509149     108.010719     219.332952
# std         8.316006      16.179947      66.758646      94.080076
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     203.000000
# 50%         9.000000      22.300000      97.666667     220.783480
# 75%        13.000000      32.000000     135.000000     220.783480
# max        47.400000      92.500000     354.000000     601.000000

# %% [markdown]
# **Reasoning**:
# The box plots show significant outliers in the numerical columns. Handle these outliers by capping them at the 99th percentile to reduce their impact on the data.

# %%
for col in numerical_cols:
    upper_limit = df_cleaned[col].quantile(0.99)
    df_cleaned[col] = np.where(df_cleaned[col] > upper_limit, upper_limit, df_cleaned[col])

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Box plot of {col} after capping outliers')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of the numerical columns to identify potential outliers using box plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = ['so2', 'no2', 'rspm', 'spm']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Box plot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Clean data
#
# ### Subtask:
# Address any inconsistencies or errors in the data (e.g., incorrect data types, outliers).

# %% [markdown]
# **Reasoning**:
# Check the data types of the columns in `df_cleaned` and convert columns that should be numerical or datetime to the correct type, handling potential errors.

# %%
import pandas as pd
import numpy as np

display(df_cleaned.info())

# Convert numerical columns
numerical_cols_to_convert = ['so2', 'no2', 'rspm', 'spm']
for col in numerical_cols_to_convert:
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')

# Convert date column
df_cleaned['date'] = pd.to_datetime(df_cleaned['date'], errors='coerce')

display(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     435742 non-null  object
#  1   sampling_date                435742 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435742 non-null  object
#  4   agency                       435742 non-null  object
#  5   type                         435742 non-null  object
#  6   so2                          435742 non-null  float64
#  7   no2                          435742 non-null  float64
#  8   rspm                         435742 non-null  float64
#  9   spm                          435742 non-null  float64
#  10  location_monitoring_station  435742 non-null  object
#  11  date                         435742 non-null  object
# dtypes: float64(4), object(8)
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because `np` was not defined. Looking at the notebook state, `np` *was* imported in a previous cell. It seems the kernel state might be inconsistent. I will include the import again to ensure the code runs correctly.

# %%
import numpy as np

missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# /tmp/ipython-input-225471578.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because `np` was not defined. Looking at the notebook state, `np` *was* imported in a previous cell. It seems the kernel state might be inconsistent. I will include the import again to ensure the code runs correctly.

# %%
import numpy as np

missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# /tmp/ipython-input-225471578.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous command failed because `np` was not defined. I need to regenerate the code block, ensuring that `np` is available.

# %%
import numpy as np

missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# /tmp/ipython-input-225471578.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Decide on a strategy for handling missing values (e.g., imputation, removal) and implement it.

# %% [markdown]
# **Reasoning**:
# Analyze the missing values, drop columns with high percentages of missing values, and then impute missing values for other columns.

# %%
missing_percentage = df.isnull().sum() / len(df) * 100

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# /tmp/ipython-input-906574110.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)
# /tmp/ipython-input-906574110.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Explore data
#
# ### Subtask:
# Display the first few rows, check data types, and look for missing values.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, check data types, and look for missing values as requested in the instructions.

# %%
display(df.head())
display(df.info())
display(df.isnull().sum())
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %% [markdown]
# **Reasoning**:
# The previous command failed because the pandas library was not imported. Import pandas and try again to load the dataset and display the head.

# %%
import pandas as pd
df = pd.read_csv('/content/data.csv', encoding='latin1')
display(df.head())
# Out:
# /tmp/ipython-input-1461667326.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data.csv', encoding='latin1')
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
# ...

# %% [markdown]
# ## Explore data
#
# ### Subtask:
# Display the first few rows, check data types, and look for missing values.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, check data types, and look for missing values as requested in the instructions.

# %%
display(df.head())
display(df.info())
display(df.isnull().sum())
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * The numerical features (so2, no2, rspm, spm) generally exhibit right-skewed distributions, indicating a prevalence of lower pollution levels but with instances of significantly higher values.
# * Moderate positive correlations were observed between no2 and rspm (approximately 0.37), and between rspm and spm (approximately 0.48). Correlations involving so2 were relatively weak.
# * The dataset includes data from 37 states and 10 types of monitoring stations, with observations concentrated in specific locations.
# * Analysis of yearly trends suggests a general decreasing trend in so2 levels over the years.
# * Yearly trends for no2 show some fluctuations but a relatively stable or slightly decreasing trend in later years.
# * Yearly trends for rspm and spm show more significant year-to-year variation without clear long-term increasing or decreasing trends.
#
# ### Insights or Next Steps
#
# * Further investigate the factors contributing to the decreasing trend in so2 levels and the stability or fluctuations in other pollutants.
# * Analyze the spatial distribution of air quality parameters to identify areas with consistently high or low pollution levels.

# %% [markdown]
# **Reasoning**:
# The previous command failed due to a UnicodeDecodeError, suggesting an issue with the file encoding. Attempt to read the CSV file again, specifying a different encoding that might be compatible with the file.

# %%
df = pd.read_csv('/content/data.csv', encoding='latin1')
display(df.head())
# Out:
# /tmp/ipython-input-4072378719.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data.csv', encoding='latin1')
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
# ...

# %% [markdown]
# ## Explore data
#
# ### Subtask:
# Display the first few rows, check data types, and look for missing values.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, check data types, and look for missing values as requested in the instructions.

# %%
display(df.head())
display(df.info())
display(df.isnull().sum())
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Decide on a strategy for handling missing values (e.g., imputation, removal) and implement it.

# %% [markdown]
# **Reasoning**:
# Analyze the missing values, drop columns with high percentages of missing values, and then impute missing values for other columns.

# %%
missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3573363362.py in <cell line: 0>()
#       7
#       8 # Impute missing values in numerical columns with the mean
# ----> 9 numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
#      10 for col in numerical_cols:
# ...

# %% [markdown]
# **Reasoning**:
# The previous code failed because `np` was not defined. I need to regenerate the code block, ensuring that `np` is available.

# %%
missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3573363362.py in <cell line: 0>()
#       7
#       8 # Impute missing values in numerical columns with the mean
# ----> 9 numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
#      10 for col in numerical_cols:
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because `np` was not defined. Looking at the notebook state, `np` *was* imported in a previous cell. It seems the kernel state might be inconsistent. I will include the import again to ensure the code runs correctly.

# %%
import numpy as np

missing_percentage = df.isnull().sum() / len(df) * 100
display(missing_percentage)

# Drop columns with more than 70% missing values
cols_to_drop = missing_percentage[missing_percentage > 70].index
df_cleaned = df.drop(columns=cols_to_drop)

# Impute missing values in numerical columns with the mean
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mean(), inplace=True)

# Impute missing values in categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include='object').columns
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

display(df_cleaned.isnull().sum())
# Out:
# stn_code                       33.064749
# sampling_date                   0.000688
# state                           0.000000
# location                        0.000688
# agency                         34.304933
# type                            1.237659
# so2                             7.951035
# no2                             3.725370
# rspm                            9.230692
# spm                            54.478797
# location_monitoring_station     6.309009
# pm2_5                          97.862497
# date                            0.001606
# dtype: float64
# /tmp/ipython-input-225471578.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Clean data
#
# ### Subtask:
# Address any inconsistencies or errors in the data (e.g., incorrect data types, outliers).

# %% [markdown]
# **Reasoning**:
# Check the data types of the columns in `df_cleaned` and convert columns that should be numerical or datetime to the correct type, handling potential errors.

# %%
display(df_cleaned.info())

# Convert numerical columns
numerical_cols_to_convert = ['so2', 'no2', 'rspm', 'spm']
for col in numerical_cols_to_convert:
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')

# Convert date column
df_cleaned['date'] = pd.to_datetime(df_cleaned['date'], errors='coerce')

display(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     435742 non-null  object
#  1   sampling_date                435742 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435742 non-null  object
#  4   agency                       435742 non-null  object
#  5   type                         435742 non-null  object
#  6   so2                          435742 non-null  float64
#  7   no2                          435742 non-null  float64
#  8   rspm                         435742 non-null  float64
#  9   spm                          435742 non-null  float64
#  10  location_monitoring_station  435742 non-null  object
#  11  date                         435742 non-null  object
# dtypes: float64(4), object(8)
# ...

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of the numerical columns to identify potential outliers using box plots.

# %%
numerical_cols = ['so2', 'no2', 'rspm', 'spm']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Box plot of {col}')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2954283867.py in <cell line: 0>()
#       1 numerical_cols = ['so2', 'no2', 'rspm', 'spm']
# ----> 2 plt.figure(figsize=(15, 10))
#       3 for i, col in enumerate(numerical_cols):
#       4     plt.subplot(2, 2, i + 1)
#       5     sns.boxplot(x=df_cleaned[col])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because `plt` was not defined. Import `matplotlib.pyplot` and `seaborn` and regenerate the box plots to visualize the distribution of numerical columns and identify potential outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = ['so2', 'no2', 'rspm', 'spm']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Box plot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# The box plots show significant outliers in the numerical columns. Handle these outliers by capping them at the 99th percentile to reduce their impact on the data.

# %%
for col in numerical_cols:
    upper_limit = df_cleaned[col].quantile(0.99)
    df_cleaned[col] = np.where(df_cleaned[col] > upper_limit, upper_limit, df_cleaned[col])

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Box plot of {col} after capping outliers')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perform exploratory data analysis (eda)
#
# ### Subtask:
# Analyze the distributions of key variables, identify correlations, and visualize the data to gain insights.

# %% [markdown]
# **Reasoning**:
# Calculate and display descriptive statistics for the numerical columns and then generate histograms for these columns to visualize their distributions, combining steps 1 and 2 of the instructions.

# %%
# Display descriptive statistics
display(df_cleaned[numerical_cols].describe())

# Generate histograms
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_cleaned[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
# Out:
#                  so2            no2           rspm            spm
# count  435742.000000  435742.000000  435742.000000  435742.000000
# mean       10.555637      25.509149     108.010719     219.332952
# std         8.316006      16.179947      66.758646      94.080076
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     203.000000
# 50%         9.000000      22.300000      97.666667     220.783480
# 75%        13.000000      32.000000     135.000000     220.783480
# max        47.400000      92.500000     354.000000     601.000000

# %% [markdown]
# **Reasoning**:
# Calculate and display the correlation matrix for the numerical columns and then create a heatmap of the correlation matrix to visualize the relationships, combining steps 3 and 4 of the instructions.

# %%
# Calculate the correlation matrix
correlation_matrix = df_cleaned[numerical_cols].corr()

# Display the correlation matrix
display(correlation_matrix)

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Air Quality Parameters')
plt.show()
# Out:
#            so2       no2      rspm       spm
# so2   1.000000  0.390892  0.184556  0.103968
# no2   0.390892  1.000000  0.367691  0.235563
# rspm  0.184556  0.367691  1.000000  0.477796
# spm   0.103968  0.235563  0.477796  1.000000

# %% [markdown]
# **Reasoning**:
# Explore the distribution of categorical variables ('state', 'location', 'type') using count plots as requested in step 5 of the instructions. Due to the large number of unique values in 'location', only the top locations will be plotted for better visualization.

# %%
categorical_cols_to_plot = ['state', 'type']

plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_cols_to_plot):
    plt.subplot(1, 2, i + 1)
    sns.countplot(y=df_cleaned[col], order=df_cleaned[col].value_counts().index)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 8))
top_locations = df_cleaned['location'].value_counts().nlargest(20).index
sns.countplot(y=df_cleaned['location'], order=top_locations)
plt.title('Top 20 Locations by Frequency')
plt.tight_layout()
plt.show()

# %%
# Aggregate data by year and calculate the mean for numerical columns
df_cleaned['year'] = df_cleaned['date'].dt.year
yearly_trend = df_cleaned.groupby('year')[numerical_cols].mean().reset_index()

# Plot the yearly trend for each air quality parameter
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.lineplot(data=yearly_trend, x='year', y=col)
    plt.title(f'Yearly Trend of {col}')
    plt.xlabel('Year')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
print("Key Findings from Exploratory Data Analysis (EDA):\n")

print("1. Descriptive Statistics, Distributions, and Correlation Matrix of Numerical Features:")
display(df_cleaned[numerical_cols].describe())

print("\nSummary of Distributions:")
print("- so2: The distribution is skewed to the right, indicating a concentration of lower values with some higher outliers.")
print("- no2: The distribution is also skewed to the right, similar to so2.")
print("- rspm: The distribution is less skewed than so2 and no2, appearing closer to a normal distribution but still with a tail to the right.")
print("- spm: The distribution is skewed to the right, with a wide spread of values.")

print("\nCorrelation Matrix:")
display(correlation_matrix)

print("\nSummary of Correlations:")
print("- There is a moderate positive correlation between no2 and rspm (approx. 0.37).")
print("- There is a moderate positive correlation between rspm and spm (approx. 0.48).")
print("- The correlations between so2 and other pollutants are relatively weak.")

print("\n2. Distributions of Categorical Variables:")
print("\nDistribution of States:")
display(df_cleaned['state'].value_counts().head())
print("\nDistribution of Types of Monitoring Stations:")
display(df_cleaned['type'].value_counts().head())
print("\nTop 20 Locations by Frequency:")
display(df_cleaned['location'].value_counts().nlargest(20).head())

print("\nSummary of Categorical Distributions:")
print(f"- The dataset contains data from {df_cleaned['state'].nunique()} states. The top states with the most observations are displayed.")
print(f"- There are {df_cleaned['type'].nunique()} types of monitoring stations. The most frequent types are displayed.")
print(f"- The data is concentrated in certain locations, with the top 20 locations accounting for a significant portion of the observations.")


print("\n3. Yearly Trends of Numerical Air Quality Parameters:")
display(yearly_trend.head())

print("\nSummary of Yearly Trends:")
print("- so2: Shows a general decreasing trend over the years.")
print("- no2: Shows some fluctuations but a relatively stable or slightly decreasing trend in later years.")
print("- rspm: Shows some year-to-year variation but no clear long-term increasing or decreasing trend.")
print("- spm: Shows significant year-to-year variation with no consistent trend, likely due to high variability and imputation.")

print("\n4. Comprehensive Summary of Key Findings:")
print("The air quality dataset provides valuable insights into pollution levels across India. The numerical features (so2, no2, rspm, spm) generally exhibit right-skewed distributions, indicating the prevalence of lower pollution levels but with instances of significantly higher values. Moderate positive correlations exist between no2, rspm, and spm. The data covers numerous states and types of monitoring stations, with observations concentrated in specific locations. Analysis of yearly trends suggests a decrease in so2 levels over time, while no2 and rspm show more stable or fluctuating patterns. The trend for spm is less clear due to high variability.")
# Out:
# Key Findings from Exploratory Data Analysis (EDA):
#
# 1. Descriptive Statistics, Distributions, and Correlation Matrix of Numerical Features:
#                  so2            no2           rspm            spm
# count  435742.000000  435742.000000  435742.000000  435742.000000
# mean       10.555637      25.509149     108.010719     219.332952
# std         8.316006      16.179947      66.758646      94.080076
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     203.000000
# 50%         9.000000      22.300000      97.666667     220.783480
# 75%        13.000000      32.000000     135.000000     220.783480
# max        47.400000      92.500000     354.000000     601.000000
# Summary of Distributions:
# - so2: The distribution is skewed to the right, indicating a concentration of lower values with some higher outliers.
# - no2: The distribution is also skewed to the right, similar to so2.
# ...
